# %% [markdown]
# <a href="https://colab.research.google.com/github/profteachkids/CHE5136_Fall2022/blob/main/BrownianMotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.graph_objects as go
import numpy as np
from plotly.subplots import make_subplots

# %%
rng=np.random.RandomState(123)

# %%
N_paths=15
N=100
r=rng.uniform(3e-3,7e-3,size=(N_paths,N))
theta = rng.uniform(0,np.pi,size=(N_paths,N))
phi = rng.uniform(0,2*np.pi, size=(N_paths,N))

# %%
dxyz=r[:,:,None]*np.stack([np.sin(theta)*np.cos(phi),np.sin(theta)*np.sin(phi),
                     np.cos(theta)],axis=2)

# %%
dxyz.shape
# Out:
# (15, 100, 3)

# %%
xyz=np.cumsum(np.concatenate([np.zeros((N_paths,1,3)),dxyz],axis=1),axis=1)

# %%
N_cols=5
N_rows=N_paths//N_cols
fig=make_subplots(rows=N_rows,cols=N_cols,specs=[[{'type':'surface'}]*N_cols]*N_rows)
for i in range(N_paths):
    fig.add_trace(go.Scatter3d(x=xyz[i,:,0],y=xyz[i,:,1],z=xyz[i,:,2],mode='lines'), row=i // N_cols+1,  col=i % N_cols +1)
fig.update_layout(width=900,height=600,template='plotly_dark',showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
[[{'type':'surface'}]*N_col]*
# Out:
# [[{'type': 'surface'}, {'type': 'surface'}, {'type': 'surface'}],
#  [{'type': 'surface'}, {'type': 'surface'}, {'type': 'surface'}],
#  [{'type': 'surface'}, {'type': 'surface'}, {'type': 'surface'}]]
